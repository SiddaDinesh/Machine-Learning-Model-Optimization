# %% [markdown]
# **Optimized Model: MobileNetV2 (FP16 Quantization + ONNX)**
#
#
#
# Inference Time (ms per image): 697.91
#
# Model Size (MB): 6.85
#
# Memory Usage (MB): 9.09
#
# **Accuracy:**
#
# Approximate Top-1 Accuracy ≈ 70.9%
#
# Optimization Techniques Applied:
#
# 1. FP16 Quantization
#
# 2. Model Conversion to ONNX
#
# **Test Environment:**
#
# Platform: Google Colab (CPU)
#
# Framework: PyTorch + ONNX Runtime
