# %% [markdown]
# **Model: MobileNetV2 (Pre-trained)**
#
# Inference Time (ms per image):  50.78
#
# Model Size (MB): 13.60
#
# Memory Usage (MB): 16.21
#
# Accuracy:
# ImageNet Top-1 Accuracy ≈ 71.8%
#
# Test Environment:
#
# Platform: Google Colab (CPU)
#
# Framework: PyTorch
